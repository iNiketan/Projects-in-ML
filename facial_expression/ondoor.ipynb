# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import defaultdict
# %matplotlib inline
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import csv
import requests

# %%
url = "https://www.ondoor.com"
html = urlopen(url)

# %%
page_src = soup(html, 'lxml')
type(page_src)
# Out:
# bs4.BeautifulSoup

# %%
page_src
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <title>Online Grocery Shopping | Free home delivery | Vegetables | Fruits | Cakes |  Flowers | Bhopal | Ondoor</title>
# <!--Let browser know website is optimized for mobile-->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# ...

# %%
data = page_src.findAll('div',attrs={'class':'col l10 m9 s12'});

# %%
data
# Out:
# [<div class="col l10 m9 s12">
#  <ul>
#  <li><a href="about-us">About Us</a></li>
#  <li><a href="privacy-policy">Privacy Policy</a></li>
#  <li><a href="faqs">FAQ's</a></li>
#  <li><a href="terms-conditions">Terms &amp; Conditions</a></li>
#  <li><a href="contact">Contact Us</a></li>
#  <li><a href="store-locator">Store Locator</a></li>
#  </ul>
#  </div>, <div class="col l10 m9 s12">
#  <ul>
#  <li><a href="category/fruits-vegetables/fruits">Fruits</a></li>
#  <li><a href="category/fruits-vegetables/vegetables">Vegetables</a></li>
#  <li><a href="category/branded-foods/namkeen">Namkeen</a></li>
#  <li><a href="category/branded-foods/biscuits-and-cookies">Biscuits &amp; Cookies </a></li>
#  <li><a href="category/dairy-bread/dairy-products">Dairy Products</a></li>
#  <li><a href="category/dairy-bread/bake-n-shake">Bake N Shake</a></li>
#  <li><a href="category/dairy-bread/dairy-products/paneer-tofu">Paneer &amp; Tofu</a></li>
# ...

# %%
'''#shop_container = page_src.findAll("div", {"class": "col l10 m9 s12 "})
#shop_container
shop_container
#all_links = page_src.find_all('a', href=re.compile("category/"))
for data in page_src.findAll('a', href=re.compile("category")):
    print(link)
#all_links
#len(all_links)
#container = page_src.findAll("li", {"class": ""})
container
for i in page_src.findAll("li",{"class":"navico"}):
    print(i.text)
for child in page_src.findAll("div", {"class": "col l10 m9 s12 "}):
    print(child)
for div in soup.findAll('div', {'class': 'col l10 m9 s12 '}):
    a = div.findAll('a')[1]
    x = ul.li.a.text.strip(), '=>', a.attrs['href']
data = page_src.findAll('div',attrs={'class':'col l10 m9 s12'});
for i in data:
    print (i.ul.li.a['href'])
for div in page_src.findAll('div',attrs={'class':'col l10 m9 s12'}):
    links = div.findAll('a', href=re.compile("category"))'''
# Out:
# '#shop_container = page_src.findAll("div", {"class": "col l10 m9 s12 "})\n#shop_container\nshop_container\n#all_links = page_src.find_all(\'a\', href=re.compile("category/"))\nfor data in page_src.findAll(\'a\', href=re.compile("category")):\n    print(link)\n#all_links\n#len(all_links)\n#container = page_src.findAll("li", {"class": ""})\ncontainer\nfor i in page_src.findAll("li",{"class":"navico"}):\n    print(i.text)\nfor child in page_src.findAll("div", {"class": "col l10 m9 s12 "}):\n    print(child)\nfor div in soup.findAll(\'div\', {\'class\': \'col l10 m9 s12 \'}):\n    a = div.findAll(\'a\')[1]\n    x = ul.li.a.text.strip(), \'=>\', a.attrs[\'href\']\ndata = page_src.findAll(\'div\',attrs={\'class\':\'col l10 m9 s12\'});\nfor i in data:\n    print (i.ul.li.a[\'href\'])\nfor div in page_src.findAll(\'div\',attrs={\'class\':\'col l10 m9 s12\'}):\n    links = div.findAll(\'a\', href=re.compile("category"))'

# %%
data1=data.pop(1)

# %%
data1
# Out:
# <div class="col l10 m9 s12">
# <ul>
# <li><a href="category/fruits-vegetables/fruits">Fruits</a></li>
# <li><a href="category/fruits-vegetables/vegetables">Vegetables</a></li>
# <li><a href="category/branded-foods/namkeen">Namkeen</a></li>
# <li><a href="category/branded-foods/biscuits-and-cookies">Biscuits &amp; Cookies </a></li>
# <li><a href="category/dairy-bread/dairy-products">Dairy Products</a></li>
# <li><a href="category/dairy-bread/bake-n-shake">Bake N Shake</a></li>
# <li><a href="category/dairy-bread/dairy-products/paneer-tofu">Paneer &amp; Tofu</a></li>
# <li><a href="category/personal-care/personal-hygiene/hand-wash">Hand Wash</a></li>
# <li><a href="category/household/detergents-and-bars/liquid-detergent">Liquid Soaps</a></li>
# <li><a href="category/personal-care/hair-care/shampoo">Shampoo</a></li>
# <li><a href="category/personal-care/hair-care/hair-conditioner">Hair Conditioners</a></li>
# ...

# %%
all_links = data1.find_all('a', href=re.compile("category"))

# %%
all_urls1 = []

# %%
all_links = data1.find_all('a', href=re.compile("category"))

# %%
for link in all_links:
    all_urls1.append('https://www.ondoor.com/' + link.get("href"))
    #print(link.get("href"))

# %%
all_urls1
# Out:
# ['https://www.ondoor.com/category/fruits-vegetables/fruits',
#  'https://www.ondoor.com/category/fruits-vegetables/vegetables',
#  'https://www.ondoor.com/category/branded-foods/namkeen',
#  'https://www.ondoor.com/category/branded-foods/biscuits-and-cookies',
#  'https://www.ondoor.com/category/dairy-bread/dairy-products',
#  'https://www.ondoor.com/category/dairy-bread/bake-n-shake',
#  'https://www.ondoor.com/category/dairy-bread/dairy-products/paneer-tofu',
#  'https://www.ondoor.com/category/personal-care/personal-hygiene/hand-wash',
#  'https://www.ondoor.com/category/household/detergents-and-bars/liquid-detergent',
#  'https://www.ondoor.com/category/personal-care/hair-care/shampoo',
#  'https://www.ondoor.com/category/personal-care/hair-care/hair-conditioner',
#  'https://www.ondoor.com/category/personal-care/deos-perfumes',
#  'https://www.ondoor.com/category/beverages/tea-coffee',
#  'https://www.ondoor.com/category/beverages/fruit-drinks-juices',
# ...

# %%
prod_img = []
prod_name = []
prod_price = []

# %%
response = requests.get('https://www.ondoor.com/category/fruits-vegetables/fruits')
Soup = soup(response.text, 'html.parser')

# %%
#text = Soup.get_text()
#print(Soup.text)

# %%
'''Brand_name=container1.findAll("div",{"class":"_3wU53n"})
x=Brand_name[0].text'''

# %%
'''text1 = Soup.find('h6')
str_cell1 = str(text1)
product_name = soup(str_cell1, "lxml").get_text()
#movie_name.append(name_of_the_movie)
'''

# %%
Soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <title>Fruit</title>
# <!--Let browser know website is optimized for mobile-->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport">
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# ...

# %%
container1 = Soup.findAll("div", {"class": "prod-name"})

# %%
container1
# Out:
# [<div class="prod-name">
#  <h6><a href="category/fruits-vegetables/fruits/other-fruits/anaar-pomegranate-500-gms" title="ANAAR - POMEGRANATE 500 Gms">Anaar - Pomegranate 500 Gms</a></h6>
#  </div>, <div class="prod-name">
#  <h6><a href="category/fruits-vegetables/fruits/apple/apple-shimla-500-gms" title="APPLE - SHIMLA 500 Gms">Apple - Shimla 500 Gms</a></h6>
#  </div>, <div class="prod-name">
#  <h6><a href="category/fruits-vegetables/fruits/apple/apple-shimla-mini-500-gms-15142" title="APPLE SHIMLA MINI 500 Gms">Apple Shimla Mini 500 Gms</a></h6>
#  </div>, <div class="prod-name">
#  <h6><a href="category/fruits-vegetables/fruits/banana/banana-premium-3-no" title="BANANA PREMIUM 3 No">Banana Premium 3 No</a></h6>
#  </div>, <div class="prod-name">
#  <h6><a href="category/fruits-vegetables/fruits/exotic-fruits/kiwi-1-no" title="Kiwi 1.0 No">Kiwi 1.0 No</a></h6>
#  </div>, <div class="prod-name">
# ...

# %%
print(len(container1))
# Out:
# 10

# %%
print(soup.prettify(container1[0]))
# Out:
# <div class="prod-name">
#  <h6>
#   <a href="category/fruits-vegetables/fruits/other-fruits/anaar-pomegranate-500-gms" title="ANAAR - POMEGRANATE 500 Gms">
#    Anaar - Pomegranate 500 Gms
#   </a>
#  </h6>
# </div>

# %%
container11 = container1[0]

# %%
product_name=container11.findAll('h6')
x=product_name[0].text

# %%
x
# Out:
# 'Anaar - Pomegranate 500 Gms'

# %%
container2 = Soup.findAll("div", {"class": "prod-ratebox"})

# %%
container2
# Out:
# [<div class="prod-ratebox">
#  <span class="ondr-rate">MR ₹<span class="WebRupee">Rs</span>64.50</span>
#  </div>, <div class="prod-ratebox">
#  <span class="ondr-rate">MR ₹<span class="WebRupee">Rs</span>54.50</span>
#  </div>, <div class="prod-ratebox">
#  <span class="ondr-rate">MR ₹<span class="WebRupee">Rs</span>49.50</span>
#  </div>, <div class="prod-ratebox">
#  <span class="ondr-rate">MR ₹<span class="WebRupee">Rs</span>12.50</span>
#  </div>, <div class="prod-ratebox">
#  <span class="ondr-rate">MR ₹<span class="WebRupee">Rs</span>40.00</span>
#  </div>, <div class="prod-ratebox">
#  <span class="ondr-rate">MR ₹<span class="WebRupee">Rs</span>35.00</span>
#  </div>, <div class="prod-ratebox">
#  <span class="ondr-rate">MR ₹<span class="WebRupee">Rs</span>20.00</span>
#  </div>, <div class="prod-ratebox">
#  <span class="ondr-rate">MRP ₹<span class="WebRupee">Rs</span>18.00</span>
#  </div>, <div class="prod-ratebox">
# ...

# %%
container12 = container2[0]

# %%
product_price=container12.findAll('span')
y=product_price[0].text

# %%
y
# Out:
# 'MR ₹Rs64.50'

# %%
container3 = Soup.findAll("div", {"class": "prod-thumb"})

# %%
container3
# Out:
# [<div class="prod-thumb">
#  <a href="category/fruits-vegetables/fruits/other-fruits/anaar-pomegranate-500-gms"><img alt="ANAAR - POMEGRANATE 500 Gms" src="https://d1s2zprapij148.cloudfront.net/image/cache/catalog/products/85-200x200.jpg" title="ANAAR - POMEGRANATE 500 Gms"/>
#  </a>
#  </div>, <div class="prod-thumb">
#  <a href="category/fruits-vegetables/fruits/apple/apple-shimla-500-gms"><img alt="APPLE - SHIMLA 500 Gms" src="https://d1s2zprapij148.cloudfront.net/image/cache/catalog/products/82-200x200.jpg" title="APPLE - SHIMLA 500 Gms"/>
#  </a>
#  </div>, <div class="prod-thumb">
#  <a href="category/fruits-vegetables/fruits/apple/apple-shimla-mini-500-gms-15142"><img alt="APPLE SHIMLA MINI 500 Gms" src="https://d1s2zprapij148.cloudfront.net/image/cache/catalog/products/16169-200x200.jpg" title="APPLE SHIMLA MINI 500 Gms"/>
#  </a>
#  </div>, <div class="prod-thumb">
# ...

# %%
container13 = container3[0]

# %%
product_price=container12.findAll('img')
